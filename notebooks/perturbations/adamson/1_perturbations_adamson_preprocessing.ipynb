# %% [markdown]
# # Preprocessing the _Adamson et al._[[1]](https://doi.org/10.1016/j.cell.2016.11.048) dataset
#
# We use `GEARS`[[2]](https://doi.org/10.1101/2022.07.12.499735) to:
# 1. Get the `No-perturb` normalization baseline for the Perturb-Seq dataset by _Adamson et al._ [[1]]([[1]](https://doi.org/10.1016/j.cell.2016.11.048)) dataset.
# 2. Extract the `adata` objects for `biolord`
# 3. Run `GEARS` as baseline comparison to `biolord`.
#
#
# [[1] Adamson, B., Norman, T. M., Jost, M., Cho, M. Y., Nuñez, J. K., Chen, Y., ... & Weissman, J. S. (2016). A multiplexed single-cell CRISPR screening platform enables systematic dissection of the unfolded protein response. Cell, 167(7), 1867-1882.](https://doi.org/10.1016/j.cell.2016.11.048)
#
# [[2] Roohani, Y., Huang, K., & Leskovec, J. (2022). GEARS": Predicting transcriptional outcomes of novel multi-gene perturbations. BioRxiv, 2022-07.](https://doi.org/10.1101/2022.07.12.499735)

# %% [markdown]
# ## Load packages

# %%
import sys
import pandas as pd
import pickle
import numpy as np
import anndata

sys.path.insert(0, "/cs/labs/mornitzan/zoe.piran/research/projects/GEARS")
from gears import PertData, GEARS
import torch

# %%
sys.path.append("../../../")
sys.path.append("../../utils/")
from paths import DATA_DIR, FIG_DIR

# %% [markdown]
# ## Set parameters

# %%
DATA_DIR_LCL = str(DATA_DIR) + "/perturbations/adamson/"
FIG_DIR_LCL = str(FIG_DIR) + "/perturbations/adamson"

# %%
device = torch.cuda.current_device()
batch_size = 32

# %% [markdown]
# ## Create `no_perturb` baseline

# %%
epoch = 0
no_perturb = True

# %%
subgroup_analysis = {}
for seed in range(1,6):
    pert_data = PertData(DATA_DIR_LCL[:-1]) # specific saved folder
    pert_data.load(data_name = "adamson")
    pert_data.prepare_split(split = "simulation", seed = seed)
    pert_data.get_dataloader(batch_size = batch_size, test_batch_size = batch_size)
    
    gears_model = GEARS(
        pert_data, 
        device = "cuda:" + str(device), 
        weight_bias_track = False, 
        proj_name = "adamson",
        exp_name = "no_perturb_seed" + str(seed)
    )
    gears_model.model_initialize(hidden_size = 64, no_perturb = no_perturb)
    subgroup_analysis[seed], subgroup_analysis_deeper, test_metrics = gears_model.train(epochs = epoch)
# Out:
# Found local copy...
# Found local copy...
# Found local copy...
# These perturbations are not in the GO graph and is thus not able to make prediction for...
# ['SRPR+ctrl' 'SLMO2+ctrl' 'TIMM23+ctrl' 'AMIGO3+ctrl' 'KCTD16+ctrl']
# Local copy of pyg dataset is detected. Loading...
# Done!
# Local copy of split is detected. Loading...
# Simulation split test composition:
# combo_seen0:0
# combo_seen1:0
# combo_seen2:0
# unseen_single:21
# Done!
# Creating dataloaders....
# Done!
# Found local copy...
# Start Training...
# Done!
# Start Testing...
# Best performing model: Test Top 20 DE MSE: 0.3849
# Start doing subgroup analysis for simulation split...
# test_combo_seen0_mse: nan
# test_combo_seen0_pearson: nan
# test_combo_seen0_mse_de: nan
# test_combo_seen0_pearson_de: nan
# test_combo_seen1_mse: nan
# test_combo_seen1_pearson: nan
# test_combo_seen1_mse_de: nan
# test_combo_seen1_pearson_de: nan
# test_combo_seen2_mse: nan
# test_combo_seen2_pearson: nan
# test_combo_seen2_mse_de: nan
# test_combo_seen2_pearson_de: nan
# test_unseen_single_mse: 0.010016158
# test_unseen_single_pearson: 0.9836310489795239
# test_unseen_single_mse_de: 0.38490468
# test_unseen_single_pearson_de: 0.915011558789885
# test_combo_seen0_mse: nan
# test_combo_seen0_pearson: nan
# test_combo_seen0_mse_de: nan
# test_combo_seen0_pearson_de: nan
# test_combo_seen1_mse: nan
# test_combo_seen1_pearson: nan
# test_combo_seen1_mse_de: nan
# test_combo_seen1_pearson_de: nan
# test_combo_seen2_mse: nan
# test_combo_seen2_pearson: nan
# test_combo_seen2_mse_de: nan
# test_combo_seen2_pearson_de: nan
# test_unseen_single_mse: 0.010016158
# test_unseen_single_pearson: 0.9836310489795239
# test_unseen_single_mse_de: 0.38490468
# test_unseen_single_pearson_de: 0.915011558789885
# Done!
# Found local copy...
# Found local copy...
# Found local copy...
# These perturbations are not in the GO graph and is thus not able to make prediction for...
# ['SRPR+ctrl' 'SLMO2+ctrl' 'TIMM23+ctrl' 'AMIGO3+ctrl' 'KCTD16+ctrl']
# Local copy of pyg dataset is detected. Loading...
# Done!
# Local copy of split is detected. Loading...
# Simulation split test composition:
# combo_seen0:0
# combo_seen1:0
# combo_seen2:0
# unseen_single:21
# Done!
# Creating dataloaders....
# Done!
# Found local copy...
# Start Training...
# Done!
# Start Testing...
# Best performing model: Test Top 20 DE MSE: 0.4207
# Start doing subgroup analysis for simulation split...
# test_combo_seen0_mse: nan
# test_combo_seen0_pearson: nan
# test_combo_seen0_mse_de: nan
# test_combo_seen0_pearson_de: nan
# test_combo_seen1_mse: nan
# test_combo_seen1_pearson: nan
# test_combo_seen1_mse_de: nan
# test_combo_seen1_pearson_de: nan
# test_combo_seen2_mse: nan
# test_combo_seen2_pearson: nan
# test_combo_seen2_mse_de: nan
# test_combo_seen2_pearson_de: nan
# test_unseen_single_mse: 0.010645245
# test_unseen_single_pearson: 0.9822805481808804
# test_unseen_single_mse_de: 0.42069998
# test_unseen_single_pearson_de: 0.8826931561406477
# test_combo_seen0_mse: nan
# test_combo_seen0_pearson: nan
# test_combo_seen0_mse_de: nan
# test_combo_seen0_pearson_de: nan
# test_combo_seen1_mse: nan
# test_combo_seen1_pearson: nan
# test_combo_seen1_mse_de: nan
# test_combo_seen1_pearson_de: nan
# test_combo_seen2_mse: nan
# test_combo_seen2_pearson: nan
# test_combo_seen2_mse_de: nan
# test_combo_seen2_pearson_de: nan
# test_unseen_single_mse: 0.010645245
# test_unseen_single_pearson: 0.9822805481808804
# test_unseen_single_mse_de: 0.42069998
# test_unseen_single_pearson_de: 0.8826931561406477
# Done!
# Found local copy...
# Found local copy...
# Found local copy...
# These perturbations are not in the GO graph and is thus not able to make prediction for...
# ['SRPR+ctrl' 'SLMO2+ctrl' 'TIMM23+ctrl' 'AMIGO3+ctrl' 'KCTD16+ctrl']
# Local copy of pyg dataset is detected. Loading...
# Done!
# Local copy of split is detected. Loading...
# Simulation split test composition:
# combo_seen0:0
# combo_seen1:0
# combo_seen2:0
# unseen_single:21
# Done!
# Creating dataloaders....
# Done!
# Found local copy...
# Start Training...
# Done!
# Start Testing...
# Best performing model: Test Top 20 DE MSE: 0.3392
# Start doing subgroup analysis for simulation split...
# test_combo_seen0_mse: nan
# test_combo_seen0_pearson: nan
# test_combo_seen0_mse_de: nan
# test_combo_seen0_pearson_de: nan
# test_combo_seen1_mse: nan
# test_combo_seen1_pearson: nan
# test_combo_seen1_mse_de: nan
# test_combo_seen1_pearson_de: nan
# test_combo_seen2_mse: nan
# test_combo_seen2_pearson: nan
# test_combo_seen2_mse_de: nan
# test_combo_seen2_pearson_de: nan
# test_unseen_single_mse: 0.009449718
# test_unseen_single_pearson: 0.9844262504333912
# test_unseen_single_mse_de: 0.33915672
# test_unseen_single_pearson_de: 0.8878374560064217
# test_combo_seen0_mse: nan
# test_combo_seen0_pearson: nan
# test_combo_seen0_mse_de: nan
# test_combo_seen0_pearson_de: nan
# test_combo_seen1_mse: nan
# test_combo_seen1_pearson: nan
# test_combo_seen1_mse_de: nan
# test_combo_seen1_pearson_de: nan
# test_combo_seen2_mse: nan
# test_combo_seen2_pearson: nan
# test_combo_seen2_mse_de: nan
# test_combo_seen2_pearson_de: nan
# test_unseen_single_mse: 0.009449718
# test_unseen_single_pearson: 0.9844262504333912
# test_unseen_single_mse_de: 0.33915672
# test_unseen_single_pearson_de: 0.8878374560064217
# Done!
# Found local copy...
# Found local copy...
# Found local copy...
# These perturbations are not in the GO graph and is thus not able to make prediction for...
# ['SRPR+ctrl' 'SLMO2+ctrl' 'TIMM23+ctrl' 'AMIGO3+ctrl' 'KCTD16+ctrl']
# Local copy of pyg dataset is detected. Loading...
# Done!
# Local copy of split is detected. Loading...
# Simulation split test composition:
# combo_seen0:0
# combo_seen1:0
# combo_seen2:0
# unseen_single:21
# Done!
# Creating dataloaders....
# Done!
# Found local copy...
# Start Training...
# Done!
# Start Testing...
# Best performing model: Test Top 20 DE MSE: 0.2887
# Start doing subgroup analysis for simulation split...
# test_combo_seen0_mse: nan
# test_combo_seen0_pearson: nan
# test_combo_seen0_mse_de: nan
# test_combo_seen0_pearson_de: nan
# test_combo_seen1_mse: nan
# test_combo_seen1_pearson: nan
# test_combo_seen1_mse_de: nan
# test_combo_seen1_pearson_de: nan
# test_combo_seen2_mse: nan
# test_combo_seen2_pearson: nan
# test_combo_seen2_mse_de: nan
# test_combo_seen2_pearson_de: nan
# test_unseen_single_mse: 0.008812609
# test_unseen_single_pearson: 0.9856189139201741
# test_unseen_single_mse_de: 0.28871977
# test_unseen_single_pearson_de: 0.8962528214350017
# test_combo_seen0_mse: nan
# test_combo_seen0_pearson: nan
# test_combo_seen0_mse_de: nan
# test_combo_seen0_pearson_de: nan
# test_combo_seen1_mse: nan
# test_combo_seen1_pearson: nan
# test_combo_seen1_mse_de: nan
# test_combo_seen1_pearson_de: nan
# test_combo_seen2_mse: nan
# test_combo_seen2_pearson: nan
# test_combo_seen2_mse_de: nan
# test_combo_seen2_pearson_de: nan
# test_unseen_single_mse: 0.008812609
# test_unseen_single_pearson: 0.9856189139201741
# test_unseen_single_mse_de: 0.28871977
# test_unseen_single_pearson_de: 0.8962528214350017
# Done!
# Found local copy...
# Found local copy...
# Found local copy...
# These perturbations are not in the GO graph and is thus not able to make prediction for...
# ['SRPR+ctrl' 'SLMO2+ctrl' 'TIMM23+ctrl' 'AMIGO3+ctrl' 'KCTD16+ctrl']
# Local copy of pyg dataset is detected. Loading...
# Done!
# Local copy of split is detected. Loading...
# Simulation split test composition:
# combo_seen0:0
# combo_seen1:0
# combo_seen2:0
# unseen_single:21
# Done!
# Creating dataloaders....
# Done!
# Found local copy...
# Start Training...
# Done!
# Start Testing...
# Best performing model: Test Top 20 DE MSE: 0.3171
# Start doing subgroup analysis for simulation split...
# test_combo_seen0_mse: nan
# test_combo_seen0_pearson: nan
# test_combo_seen0_mse_de: nan
# test_combo_seen0_pearson_de: nan
# test_combo_seen1_mse: nan
# test_combo_seen1_pearson: nan
# test_combo_seen1_mse_de: nan
# test_combo_seen1_pearson_de: nan
# test_combo_seen2_mse: nan
# test_combo_seen2_pearson: nan
# test_combo_seen2_mse_de: nan
# test_combo_seen2_pearson_de: nan
# test_unseen_single_mse: 0.009298213
# test_unseen_single_pearson: 0.9847454517677867
# test_unseen_single_mse_de: 0.31713462
# test_unseen_single_pearson_de: 0.9130561585474255
# test_combo_seen0_mse: nan
# test_combo_seen0_pearson: nan
# test_combo_seen0_mse_de: nan
# test_combo_seen0_pearson_de: nan
# test_combo_seen1_mse: nan
# test_combo_seen1_pearson: nan
# test_combo_seen1_mse_de: nan
# test_combo_seen1_pearson_de: nan
# test_combo_seen2_mse: nan
# test_combo_seen2_pearson: nan
# test_combo_seen2_mse_de: nan
# test_combo_seen2_pearson_de: nan
# test_unseen_single_mse: 0.009298213
# test_unseen_single_pearson: 0.9847454517677867
# test_unseen_single_mse_de: 0.31713462
# test_unseen_single_pearson_de: 0.9130561585474255
# Done!

# %%
res = {}
for key in subgroup_analysis:
    res[f"mse_de_seed{key}"] = pd.DataFrame(subgroup_analysis[key]).T["mse_de"]

# %%
with open(DATA_DIR_LCL + "no_perturb_subgroup_analysis.pkl", "wb") as f:
    pickle.dump(subgroup_analysis, f)

# %%
pd.DataFrame(res).to_csv(DATA_DIR_LCL + "no_perturb_mse_de_seeds.csv")

# %%
pd.DataFrame(res)
# Out:
#                mse_de_seed1  mse_de_seed2  mse_de_seed3  mse_de_seed4  \
# combo_seen0             NaN           NaN           NaN           NaN
# combo_seen1             NaN           NaN           NaN           NaN
# combo_seen2             NaN           NaN           NaN           NaN
# unseen_single      0.384905        0.4207      0.339157       0.28872
#
#                mse_de_seed5
# combo_seen0             NaN
# combo_seen1             NaN
# combo_seen2             NaN
# unseen_single      0.317135

# %% [markdown]
# ## Set `adata`

# %%
adata = pert_data.adata.copy()

# %%
for seed in range(1,6):
    with open(DATA_DIR_LCL + f"adamson/splits/adamson_simulation_{seed}_0.75.pkl", "rb") as f:
        split_data = pickle.load(f)
        pert2set = {}
        for i,j in split_data.items():
            for x in j:
                pert2set[x] = i
        
        subgroup = pickle.load(open(DATA_DIR_LCL + f"adamson/splits/adamson_simulation_{seed}_0.75_subgroup.pkl", "rb"))
        adata.obs[f"split{seed}"] = [pert2set[i] for i in adata.obs["condition"].values]
        pert2subgroup = {}
        for i,j in subgroup["test_subgroup"].items():
            for x in j:
                pert2subgroup[x] = i
        
        adata.obs[f"subgroup{seed}"] = adata.obs["condition"].apply(lambda x: pert2subgroup[x] if x in pert2subgroup else 'Train/Val')
        rename = {
            'train': 'train',
             'test': 'ood',
             'val': 'test'
        }
        adata.obs[f'split{seed}'] = adata.obs[f'split{seed}'].apply(lambda x: rename[x])

# %%
adata.obs["perturbation"] = [cond.split("+")[0] for cond in adata.obs["condition"]]
adata.obs["perturbation"] = adata.obs["perturbation"].astype("category")

# %%
go_path = DATA_DIR_LCL + 'adamson/go.csv'
gene_path = DATA_DIR_LCL + 'essential_all_data_pert_genes.pkl'
df = pd.read_csv(go_path)
df = df.groupby('target').apply(lambda x: x.nlargest(20 + 1, ['importance'])).reset_index(drop = True)
with open(gene_path, 'rb') as f:
    gene_list = pickle.load(f)
    
df = df[df["source"].isin(gene_list)]

# %%
def get_map(pert):
    tmp = pd.DataFrame(np.zeros(len(gene_list)), index=gene_list)
    tmp.loc[df[df.target == pert].source.values, :] = df[df.target == pert].importance.values[:, np.newaxis]
    return tmp.values.flatten()

# %%
pert2neighbor =  {i: get_map(i) for i in list(adata.obs["perturbation"].cat.categories)}    
adata.uns["pert2neighbor"] = pert2neighbor

# %%
pert2neighbor = np.asarray([val for val in adata.uns["pert2neighbor"].values()])
keep_idx = pert2neighbor.sum(0) > 0

name_map = dict(adata.obs[["condition", "condition_name"]].drop_duplicates().values)
ctrl = np.asarray(adata[adata.obs["condition"].isin(["ctrl"])].X.mean(0)).flatten()

# %%
df_perts_expression = pd.DataFrame(adata.X.A, index=adata.obs_names, columns=adata.var_names)
df_perts_expression["condition"] = adata.obs["condition"]
df_perts_expression = df_perts_expression.groupby(["condition"]).mean()
df_perts_expression = df_perts_expression.reset_index()

single_perts_condition = []
single_pert_val = []
double_perts = []
for pert in adata.obs["condition"].cat.categories:
    if len(pert.split("+")) == 1:
        continue
    elif "ctrl" in pert:
        single_perts_condition.append(pert)
        p1, p2 = pert.split("+")
        if p2 == "ctrl":
            single_pert_val.append(p1)
        else:
            single_pert_val.append(p2)
single_perts_condition.append("ctrl")
single_pert_val.append("ctrl")

df_singleperts_expression = pd.DataFrame(df_perts_expression.set_index("condition").loc[single_perts_condition].values, index=single_pert_val)
df_singleperts_emb = np.asarray([adata.uns["pert2neighbor"][p1][keep_idx] for p1 in df_singleperts_expression.index])

df_singleperts_condition = pd.Index(single_perts_condition)
df_single_pert_val = pd.Index(single_pert_val)

# %%
adata_single = anndata.AnnData(X=df_singleperts_expression.values, var=adata.var.copy(), dtype=df_singleperts_expression.values.dtype)
adata_single.obs_names = df_singleperts_condition
adata_single.obs["condition"] = df_singleperts_condition
adata_single.obs["perts_name"] = df_single_pert_val
adata_single.obsm["perturbation_neighbors"] = df_singleperts_emb

# %%
for split_seed in range(1,6):
    adata_single.obs[f"split{split_seed}"] = None
    adata_single.obs[f"subgroup{split_seed}"] = "Train/Val"
    for cat in ["train","test","ood"]:
        cat_idx = adata_single.obs["condition"].isin(adata[adata.obs[f"split{split_seed}"] == cat].obs["condition"].cat.categories)
        adata_single.obs.loc[cat_idx ,f"split{split_seed}"] = cat
        if cat == "ood":
            adata_single.obs.loc[cat_idx ,f"subgroup{split_seed}"] = "unseen_single"

# %%
adata_single.write(DATA_DIR_LCL + "adamson/adamson_single_biolord.h5ad")

# %%
adata.write(DATA_DIR_LCL + "adamson/adamson_biolord.h5ad")

# %% [markdown]
# ## Train `GEARS` models

# %%
epoch = 15
no_perturb = False

# %%
subgroup_analysis_gears = {}
for seed in range(1,6):
    pert_data = PertData(DATA_DIR_LCL[:-1]) # specific saved folder
    pert_data.load(data_name = "adamson")
    pert_data.prepare_split(split = "simulation", seed = seed)
    pert_data.get_dataloader(batch_size = batch_size, test_batch_size = batch_size)
    
    gears_model = GEARS(
        pert_data, 
        device = "cuda:" + str(device), 
        weight_bias_track = False, 
        proj_name = "adamson",
        exp_name = "gears_seed" + str(seed)
    )
    gears_model.model_initialize(hidden_size = 64, no_perturb = no_perturb)
    subgroup_analysis_gears[seed], subgroup_analysis_deeper, test_metrics = gears_model.train(epochs = epoch)
# Out:
# Found local copy...
# Found local copy...
# Found local copy...
# These perturbations are not in the GO graph and is thus not able to make prediction for...
# ['SRPR+ctrl' 'SLMO2+ctrl' 'TIMM23+ctrl' 'AMIGO3+ctrl' 'KCTD16+ctrl']
# Local copy of pyg dataset is detected. Loading...
# Done!
# Local copy of split is detected. Loading...
# Simulation split test composition:
# combo_seen0:0
# combo_seen1:0
# combo_seen2:0
# unseen_single:21
# Done!
# Creating dataloaders....
# Done!
# Found local copy...
# Start Training...
# Epoch 1 Step 1 Train Loss: 0
# Epoch 2 Step 1201 Train Loss: 0.6258
# Epoch 2 Step 1251 Train Loss: 0.6467
# Epoch 2 Step 1301 Train Loss: 0.5809
# Epoch 2 Step 1351 Train Loss: 0.4550
# Epoch 2 Step 1401 Train Loss: 0.5382
# Epoch 2 Step 1451 Train Loss: 0.5606
# Epoch 2 Step 1501 Train Loss: 0.5727
# Epoch 2 Step 1551 Train Loss: 0.4655
# Epoch 2 Step 1601 Train Loss: 0.5743
# Epoch 2: Train Overall MSE: 0.0044 Validation Overall MSE: 0.0069.
# Train Top 20 DE MSE: 0.1067 Validation Top 20 DE MSE: 0.2300.
# Epoch 3 Step 1 Train Loss: 0.4731
# Epoch 3 Step 51 Train Loss: 0.5461
# Epoch 3 Step 101 Train Loss: 0.5137
# Epoch 3 Step 151 Train Loss: 0.5532
# Epoch 3 Step 201 Train Loss: 0.5467
# Epoch 3 Step 251 Train Loss: 0.5731
# Epoch 3 Step 301 Train Loss: 0.5647
# Epoch 3 Step 351 Train Loss: 0.4772
# Epoch 3 Step 401 Train Loss: 0.4969
# Epoch 3 Step 451 Train Loss: 0.5713
# Epoch 3 Step 501 Train Loss: 0.5281
# Epoch 3 Step 551 Train Loss: 0.5521
# Epoch 3 Step 601 Train Loss: 0.5278
# Epoch 3 Step 651 Train Loss: 0.4833
# Epoch 3 Step 701 Train Loss: 0.5043
# Epoch 3 Step 751 Train Loss: 0.5604
# Epoch 3 Step 801 Train Loss: 0.6316
# Epoch 3 Step 851 Train Loss: 0.5873
# Epoch 3 Step 901 Train Loss: 0.5004
# Epoch 3 Step 951 Train Loss: 0.5865
# Epoch 3 Step 1001 Train Loss: 0.6408
# Epoch 3 Step 1051 Train Loss: 0.5409
# Epoch 3 Step 1101 Train Loss: 0.6026
# Epoch 3 Step 1151 Train Loss: 0.5985
# Epoch 3 Step 1201 Train Loss: 0.4766
# Epoch 3 Step 1251 Train Loss: 0.6645
# Epoch 3 Step 1301 Train Loss: 0.5819
# Epoch 3 Step 1351 Train Loss: 0.4738
# Epoch 3 Step 1401 Train Loss: 0.4669
# Epoch 3 Step 1451 Train Loss: 0.6220
# Epoch 3 Step 1501 Train Loss: 0.5960
# Epoch 3 Step 1551 Train Loss: 0.5697
# Epoch 3 Step 1601 Train Loss: 0.4759
# Epoch 3: Train Overall MSE: 0.0034 Validation Overall MSE: 0.0064.
# Train Top 20 DE MSE: 0.0847 Validation Top 20 DE MSE: 0.1921.
# Epoch 4 Step 1 Train Loss: 0.5619
# Epoch 4 Step 51 Train Loss: 0.6596
# Epoch 4 Step 101 Train Loss: 0.5432
# Epoch 4 Step 151 Train Loss: 0.5294
# Epoch 4 Step 201 Train Loss: 0.7002
# Epoch 4 Step 251 Train Loss: 0.6080
# Epoch 4 Step 301 Train Loss: 0.5388
# Epoch 4 Step 351 Train Loss: 0.5711
# Epoch 4 Step 401 Train Loss: 0.5003
# Epoch 4 Step 451 Train Loss: 0.5128
# Epoch 4 Step 501 Train Loss: 0.7538
# Epoch 4 Step 551 Train Loss: 0.5565
# Epoch 4 Step 601 Train Loss: 0.5227
Train Overall MSE: 0.0029 Validation Overall MSE: 0.0061.
# Train Top 20 DE MSE: 0.0732 Validation Top 20 DE MSE: 0.1937.
# Epoch 6 Step 1 Train Loss: 0.5312
# Epoch 6 Step 51 Train Loss: 0.5453
# Epoch 6 Step 101 Train Loss: 0.5737
# Epoch 6 Step 151 Train Loss: 0.4768
# Epoch 6 Step 201 Train Loss: 0.5105
# Epoch 6 Step 251 Train Loss: 0.7914
# Epoch 6 Step 301 Train Loss: 0.5305
# Epoch 6 Step 351 Train Loss: 0.5618
# Epoch 6 Step 401 Train Loss: 0.5038
# Epoch 6 Step 451 Train Loss: 0.6033
# Epoch 6 Step 501 Train Loss: 0.5591
# Epoch 6 Step 551 Train Loss: 0.5230
# Epoch 6 Step 601 Train Loss: 0.5457
# Epoch 6 Step 651 Train Loss: 0.5588
# Epoch 6 Step 701 Train Loss: 0.6270
# Epoch 6 Step 751 Train Loss: 0.6343
# Epoch 6 Step 801 Train Loss: 0.4447
# Epoch 6 Step 851 Train Loss: 0.6201
# Epoch 6 Step 901 Train Loss: 0.5383
# Epoch 6 Step 951 Train Loss: 0.5737
# Epoch 6 Step 1001 Train Loss: 0.5902
# Epoch 6 Step 1051 Train Loss: 0.4986
# Epoch 6 Step 1101 Train Loss: 0.5285
# Epoch 6 Step 1151 Train Loss: 0.5829
# Epoch 6 Step 1201 Train Loss: 0.5462
# Epoch 6 Step 1251 Train Loss: 0.5097
# Epoch 6 Step 1301 Train Loss: 0.5005
# Epoch 6 Step 1351 Train Loss: 0.5425
# Epoch 6 Step 1401 Train Loss: 0.5621
# Epoch 6 Step 1451 Train Loss: 0.4869
# Epoch 6 Step 1501 Train Loss: 0.6231
# Epoch 6 Step 1551 Train Loss: 0.4990
# Epoch 6 Step 1601 Train Loss: 0.5891
# Epoch 6: Train Overall MSE: 0.0029 Validation Overall MSE: 0.0061.
# Train Top 20 DE MSE: 0.0745 Validation Top 20 DE MSE: 0.1969.
# Epoch 7 Step 1 Train Loss: 0.6579
# Epoch 7 Step 51 Train Loss: 0.5563
# Epoch 7 Step 101 Train Loss: 0.4899
# Epoch 7 Step 151 Train Loss: 0.5253
# Epoch 7 Step 201 Train Loss: 0.5664
# Epoch 7 Step 251 Train Loss: 0.6610
# Epoch 7 Step 301 Train Loss: 0.5512
# Epoch 7 Step 351 Train Loss: 0.5596
# Epoch 7 Step 401 Train Loss: 0.5075
# Epoch 7 Step 451 Train Loss: 0.6103
# Epoch 7 Step 501 Train Loss: 0.6004
# Epoch 7 Step 551 Train Loss: 0.5554
# Epoch 7 Step 601 Train Loss: 0.5974
# Epoch 7 Step 651 Train Loss: 0.6453
# Epoch 7 Step 701 Train Loss: 0.5500
# Epoch 7 Step 751 Train Loss: 0.5043
# Epoch 7 Step 801 Train Loss: 0.5624
# Epoch 7 Step 851 Train Loss: 0.5297
# Epoch 7 Step 901 Train Loss: 0.6360
# Epoch 7 Step 951 Train Loss: 0.6054
# Epoch 7 Step 1001 Train Loss: 0.5959
# Epoch 7 Step 1051 Train Loss: 0.5695
# Epoch 7 Step 1101 Train Loss: 0.5685
# Epoch 7 Step 1151 Train Loss: 0.5022
# Epoch 7 Step 1201 Train Loss: 0.5761
# Epoch 7 Step 1251 Train Loss: 0.5417
# Epoch 7 Step 1301 Train Loss: 0.5222
# Epoch 7 Step 1351 Train Loss: 0.5447
# Epoch 7 Step 1401 Train Loss: 0.5832
# Epoch 7 Step 1451 Train Loss: 0.5468
# Epoch 7 Step 1501 Train Loss: 0.5301
# Epoch 7 Step 1551 Train Loss: 0.5809
# Epoch 7 Step 1601 Train Loss: 0.6633
# Epoch 7: Train Overall MSE: 0.0029 Validation Overall MSE: 0.0060.
# Train Top 20 DE MSE: 0.
# Epoch 9 Step 1051 Train Loss: 0.6820
# Epoch 9 Step 1101 Train Loss: 0.5558
# Epoch 9 Step 1151 Train Loss: 0.5757
# Epoch 9 Step 1201 Train Loss: 0.5844
# Epoch 9 Step 1251 Train Loss: 0.5423
# Epoch 9 Step 1301 Train Loss: 0.5927
# Epoch 9 Step 1351 Train Loss: 0.6680
# Epoch 9 Step 1401 Train Loss: 0.6045
# Epoch 9 Step 1451 Train Loss: 0.6426
# Epoch 9 Step 1501 Train Loss: 0.6412
# Epoch 9 Step 1551 Train Loss: 0.5351
# Epoch 9 Step 1601 Train Loss: 0.5464
# Epoch 9: Train Overall MSE: 0.0029 Validation Overall MSE: 0.0061.
# Train Top 20 DE MSE: 0.0758 Validation Top 20 DE MSE: 0.1936.
# Epoch 10 Step 1 Train Loss: 0.6341
# Epoch 10 Step 51 Train Loss: 0.5384
# Epoch 10 Step 101 Train Loss: 0.6245
# Epoch 10 Step 151 Train Loss: 0.6277
# Epoch 10 Step 201 Train Loss: 0.5737
# Epoch 10 Step 251 Train Loss: 0.6016
# Epoch 10 Step 301 Train Loss: 0.6729
# Epoch 10 Step 351 Train Loss: 0.5729
# Epoch 10 Step 401 Train Loss: 0.5367
# Epoch 10 Step 451 Train Loss: 0.6905
# Epoch 10 Step 501 Train Loss: 0.5059
# Epoch 10 Step 551 Train Loss: 0.5293
# Epoch 10 Step 601 Train Loss: 0.5366
# Epoch 10 Step 651 Train Loss: 0.5575
# Epoch 10 Step 701 Train Loss: 0.5900
# Epoch 10 Step 751 Train Loss: 0.5354
# Epoch 10 Step 801 Train Loss: 0.5458
# Epoch 10 Step 851 Train Loss: 0.5869
# Epoch 10 Step 901 Train Loss: 0.5620
# Epoch 10 Step 951 Train Loss: 0.5992
# Epoch 10 Step 1001 Train Loss: 0.5297
# Epoch 10 Step 1051 Train Loss: 0.5453
# Epoch 10 Step 1101 Train Loss: 0.5634
# Epoch 10 Step 1151 Train Loss: 0.5168
# Epoch 10 Step 1201 Train Loss: 0.5739
# Epoch 10 Step 1251 Train Loss: 0.5426
# Epoch 10 Step 1301 Train Loss: 0.5831
# Epoch 10 Step 1351 Train Loss: 0.4935
# Epoch 10 Step 1401 Train Loss: 0.6640
# Epoch 10 Step 1451 Train Loss: 0.6273
# Epoch 10 Step 1501 Train Loss: 0.5321
# Epoch 10 Step 1551 Train Loss: 0.7254
# Epoch 10 Step 1601 Train Loss: 0.7008
# Epoch 10: Train Overall MSE: 0.0028 Validation Overall MSE: 0.0061.
# Train Top 20 DE MSE: 0.0767 Validation Top 20 DE MSE: 0.1969.
# Epoch 11 Step 1 Train Loss: 0.6272
# Epoch 11 Step 51 Train Loss: 0.6136
# Epoch 11 Step 101 Train Loss: 0.5921
# Epoch 11 Step 151 Train Loss: 0.5386
# Epoch 11 Step 201 Train Loss: 0.5344
# Epoch 11 Step 251 Train Loss: 0.7451
# Epoch 11 Step 301 Train Loss: 0.5429
# Epoch 11 Step 351 Train Loss: 0.5721
# Epoch 11 Step 401 Train Loss: 0.5478
# Epoch 11 Step 451 Train Loss: 0.5495
# Epoch 11 Step 501 Train Loss: 0.6128
Train Overall MSE: 0.0029 Validation Overall MSE: 0.0061.
# Train Top 20 DE MSE: 0.0720 Validation Top 20 DE MSE: 0.1903.
# Epoch 13 Step 1 Train Loss: 0.6074
# Epoch 13 Step 51 Train Loss: 0.5995
# Epoch 13 Step 101 Train Loss: 0.5673
# Epoch 13 Step 151 Train Loss: 0.6422
# Epoch 13 Step 201 Train Loss: 0.5787
# Epoch 13 Step 251 Train Loss: 0.5314
# Epoch 13 Step 301 Train Loss: 0.6240
# Epoch 13 Step 351 Train Loss: 0.5666
# Epoch 13 Step 401 Train Loss: 0.5674
# Epoch 13 Step 451 Train Loss: 0.6088
# Epoch 13 Step 501 Train Loss: 0.6120
# Epoch 13 Step 551 Train Loss: 0.5537
# Epoch 13 Step 601 Train Loss: 0.5704
# Epoch 13 Step 651 Train Loss: 0.6221
# Epoch 13 Step 701 Train Loss: 0.7200
# Epoch 13 Step 751 Train Loss: 0.5945
# Epoch 13 Step 801 Train Loss: 0.5757
# Epoch 13 Step 851 Train Loss: 0.6253
# Epoch 13 Step 901 Train Loss: 0.5639
# Epoch 13 Step 951 Train Loss: 0.5462
# Epoch 13 Step 1001 Train Loss: 0.5744
# Epoch 13 Step 1051 Train Loss: 0.5194
# Epoch 13 Step 1101 Train Loss: 0.5550
# Epoch 13 Step 1151 Train Loss: 0.6274
# Epoch 13 Step 1201 Train Loss: 0.5343
# Epoch 13 Step 1251 Train Loss: 0.7228
# Epoch 13 Step 1301 Train Loss: 0.6090
# Epoch 13 Step 1351 Train Loss: 0.5741
# Epoch 13 Step 1401 Train Loss: 0.5296
# Epoch 13 Step 1451 Train Loss: 0.6257
# Epoch 13 Step 1501 Train Loss: 0.5321
# Epoch 13 Step 1551 Train Loss: 0.5967
# Epoch 13 Step 1601 Train Loss: 0.6546
# Epoch 13: Train Overall MSE: 0.0028 Validation Overall MSE: 0.0060.
# Train Top 20 DE MSE: 0.0748 Validation Top 20 DE MSE: 0.1886.
# Epoch 14 Step 1 Train Loss: 0.6386
# Epoch 14 Step 51 Train Loss: 0.5973
# Epoch 14 Step 101 Train Loss: 0.6300
# Epoch 14 Step 151 Train Loss: 0.4977
# Epoch 14 Step 201 Train Loss: 0.6206
# Epoch 14 Step 251 Train Loss: 0.6373
# Epoch 14 Step 301 Train Loss: 0.5664
# Epoch 14 Step 351 Train Loss: 0.5331
# Epoch 14 Step 401 Train Loss: 0.6590
# Epoch 14 Step 451 Train Loss: 0.4633
# Epoch 14 Step 501 Train Loss: 0.5655
# Epoch 14 Step 551 Train Loss: 0.5949
# Epoch 14 Step 601 Train Loss: 0.6139
# Epoch 14 Step 651 Train Loss: 0.5366
# Epoch 14 Step 701 Train Loss: 0.7334
# Epoch 14 Step 751 Train Loss: 0.5872
# Epoch 14 Step 801 Train Loss: 0.5711
# Epoch 14 Step 851 Train Loss: 0.5431
# Epoch 14 Step 901 Train Loss: 0.6345
# Epoch 14 Step 951 Train Loss: 0.5202
# Epoch 14 Step 1001 Train Loss: 0.6131
# Epoch 14 Step 1051 Train Loss: 0.6205
# Epoch 14 Step 1101 Train Loss: 0.6730
# Epoch 14 Step 1151 Train Loss: 0.4854
# Epoch 14 Step 1201 Train Loss: 0.6486
# Epoch 14 Step 1251 Train Loss: 0.5549
# Epoch 14 Step 1301 Train Loss: 0.5275
# Epoch 14 Step 1351 Train Loss: 0.5125
# Epoch 14 Step 1401 Train Loss: 0.5825
# Epoch 14 Step 1451 Train Loss: 0.6171
# Epoch 14 Step 1501 Train Loss: 0.5231
# Epoch 14 Step 1551 Train Loss: 0.6934
# Epoch 14 Step 1601 Train Loss: 0.6195
# Epoch 14: Train Overall MSE: 0.0029 Validation Overall MSE: 0.0060.
# Train Top 20 DE MSE: 0.
# Epoch 3 Step 251 Train Loss: 0.5363
# Epoch 3 Step 301 Train Loss: 0.5741
# Epoch 3 Step 351 Train Loss: 0.5122
# Epoch 3 Step 401 Train Loss: 0.5378
# Epoch 3 Step 451 Train Loss: 0.5598
# Epoch 3 Step 501 Train Loss: 0.5158
# Epoch 3 Step 551 Train Loss: 0.6584
# Epoch 3 Step 601 Train Loss: 0.5172
# Epoch 3 Step 651 Train Loss: 0.4972
# Epoch 3 Step 701 Train Loss: 0.5860
# Epoch 3 Step 751 Train Loss: 0.5921
# Epoch 3 Step 801 Train Loss: 0.5371
# Epoch 3 Step 851 Train Loss: 0.4615
# Epoch 3 Step 901 Train Loss: 0.4961
# Epoch 3 Step 951 Train Loss: 0.5338
# Epoch 3 Step 1001 Train Loss: 0.6714
# Epoch 3 Step 1051 Train Loss: 0.5290
# Epoch 3 Step 1101 Train Loss: 0.4873
# Epoch 3 Step 1151 Train Loss: 0.5530
# Epoch 3 Step 1201 Train Loss: 0.5093
# Epoch 3 Step 1251 Train Loss: 0.5445
# Epoch 3 Step 1301 Train Loss: 0.4583
# Epoch 3 Step 1351 Train Loss: 0.5088
# Epoch 3 Step 1401 Train Loss: 0.5591
# Epoch 3 Step 1451 Train Loss: 0.5479
# Epoch 3 Step 1501 Train Loss: 0.5378
# Epoch 3 Step 1551 Train Loss: 0.5978
# Epoch 3 Step 1601 Train Loss: 0.5092
# Epoch 3: Train Overall MSE: 0.0032 Validation Overall MSE: 0.0034.
# Train Top 20 DE MSE: 0.0685 Validation Top 20 DE MSE: 0.1172.
# Epoch 4 Step 1 Train Loss: 0.4718
# Epoch 4 Step 51 Train Loss: 0.6294
# Epoch 4 Step 101 Train Loss: 0.5897
# Epoch 4 Step 151 Train Loss: 0.5514
# Epoch 4 Step 201 Train Loss: 0.5551
# Epoch 4 Step 251 Train Loss: 0.5506
# Epoch 4 Step 301 Train Loss: 0.5814
# Epoch 4 Step 351 Train Loss: 0.5664
# Epoch 4 Step 401 Train Loss: 0.5067
# Epoch 4 Step 451 Train Loss: 0.5956
# Epoch 4 Step 501 Train Loss: 0.5636
# Epoch 4 Step 551 Train Loss: 0.5500
# Epoch 4 Step 601 Train Loss: 0.4918
# Epoch 4 Step 651 Train Loss: 0.5829
# Epoch 4 Step 701 Train Loss: 0.5938
# Epoch 4 Step 751 Train Loss: 0.4682
# Epoch 4 Step 801 Train Loss: 0.6894
# Epoch 4 Step 851 Train Loss: 0.4922
# Epoch 4 Step 901 Train Loss: 0.5308
# Epoch 4 Step 951 Train Loss: 0.5072
# Epoch 4 Step 1001 Train Loss: 0.8709
# Epoch 4 Step 1051 Train Loss: 0.5874
# Epoch 4 Step 1101 Train Loss: 0.5537
# Epoch 4 Step 1151 Train Loss: 0.5055
# Epoch 4 Step 1201 Train Loss: 0.5305
# Epoch 4 Step 1251 Train Loss: 0.5257
# Epoch 4 Step 1301 Train Loss: 0.6139
# Epoch 4 Step 1351 Train Loss: 0.6493
# Epoch 4 Step 1401 Train Loss: 0.7481
# Epoch 4 Step 1451 Train Loss: 0.5659
# Epoch 4 Step 1501 Train Loss: 0.5811
# Epoch 4 Step 1551 Train Loss: 0.5407
# Epoch 4 Step 1601 Train Loss: 0.5861
# Epoch 4: Train Overall MSE: 0.0029 Validation Overall MSE: 0.
# Epoch 6 Step 1051 Train Loss: 0.6274
# Epoch 6 Step 1101 Train Loss: 0.5870
# Epoch 6 Step 1151 Train Loss: 0.5110
# Epoch 6 Step 1201 Train Loss: 0.6205
# Epoch 6 Step 1251 Train Loss: 0.6153
# Epoch 6 Step 1301 Train Loss: 0.6640
# Epoch 6 Step 1351 Train Loss: 0.5985
# Epoch 6 Step 1401 Train Loss: 0.6313
# Epoch 6 Step 1451 Train Loss: 0.5507
# Epoch 6 Step 1501 Train Loss: 0.5974
# Epoch 6 Step 1551 Train Loss: 0.5598
# Epoch 6 Step 1601 Train Loss: 0.5566
# Epoch 6: Train Overall MSE: 0.0028 Validation Overall MSE: 0.0032.
# Train Top 20 DE MSE: 0.0600 Validation Top 20 DE MSE: 0.1160.
# Epoch 7 Step 1 Train Loss: 0.5497
# Epoch 7 Step 51 Train Loss: 0.6980
# Epoch 7 Step 101 Train Loss: 0.5582
# Epoch 7 Step 151 Train Loss: 0.5924
# Epoch 7 Step 201 Train Loss: 0.5576
# Epoch 7 Step 251 Train Loss: 0.6091
# Epoch 7 Step 301 Train Loss: 0.5502
# Epoch 7 Step 351 Train Loss: 0.5854
# Epoch 7 Step 401 Train Loss: 0.6320
# Epoch 7 Step 451 Train Loss: 0.5303
# Epoch 7 Step 501 Train Loss: 0.5557
# Epoch 7 Step 551 Train Loss: 0.7008
# Epoch 7 Step 601 Train Loss: 0.6093
# Epoch 7 Step 651 Train Loss: 0.8361
# Epoch 7 Step 701 Train Loss: 0.5938
# Epoch 7 Step 751 Train Loss: 0.4782
# Epoch 7 Step 801 Train Loss: 0.6119
# Epoch 7 Step 851 Train Loss: 0.5482
# Epoch 7 Step 901 Train Loss: 0.7615
# Epoch 7 Step 951 Train Loss: 0.5561
# Epoch 7 Step 1001 Train Loss: 0.6760
# Epoch 7 Step 1051 Train Loss: 0.5623
# Epoch 7 Step 1101 Train Loss: 0.5675
# Epoch 7 Step 1151 Train Loss: 0.5024
# Epoch 7 Step 1201 Train Loss: 0.5169
# Epoch 7 Step 1251 Train Loss: 0.5680
# Epoch 7 Step 1301 Train Loss: 0.5899
# Epoch 7 Step 1351 Train Loss: 0.6430
# Epoch 7 Step 1401 Train Loss: 0.6136
# Epoch 7 Step 1451 Train Loss: 0.6012
# Epoch 7 Step 1501 Train Loss: 0.6199
# Epoch 7 Step 1551 Train Loss: 0.4957
# Epoch 7 Step 1601 Train Loss: 0.8401
# Epoch 7: Train Overall MSE: 0.0028 Validation Overall MSE: 0.0031.
# Train Top 20 DE MSE: 0.0637 Validation Top 20 DE MSE: 0.1120.
# Epoch 8 Step 1 Train Loss: 0.5333
# Epoch 8 Step 51 Train Loss: 0.5921
# Epoch 8 Step 101 Train Loss: 0.5488
# Epoch 8 Step 151 Train Loss: 0.5723
# Epoch 8 Step 201 Train Loss: 0.5830
# Epoch 8 Step 251 Train Loss: 0.6059
# Epoch 8 Step 301 Train Loss: 0.5739
# Epoch 8 Step 351 Train Loss: 0.6006
# Epoch 8 Step 401 Train Loss: 0.5735
# Epoch 8 Step 451 Train Loss: 0.5820
# Epoch 8 Step 501 Train Loss: 0.5896
# Epoch 8 Step 551 Train Loss: 0.5817
Train Overall MSE: 0.0028 Validation Overall MSE: 0.0032.
# Train Top 20 DE MSE: 0.0618 Validation Top 20 DE MSE: 0.1117.
# Epoch 12 Step 1 Train Loss: 0.5205
# Epoch 12 Step 51 Train Loss: 0.5947
# Epoch 12 Step 101 Train Loss: 0.6886
# Epoch 12 Step 151 Train Loss: 0.6813
# Epoch 12 Step 201 Train Loss: 0.6523
# Epoch 12 Step 251 Train Loss: 0.5719
# Epoch 12 Step 301 Train Loss: 0.5520
# Epoch 12 Step 351 Train Loss: 0.5310
# Epoch 12 Step 401 Train Loss: 0.5826
# Epoch 12 Step 451 Train Loss: 0.6098
# Epoch 12 Step 501 Train Loss: 0.5415
# Epoch 12 Step 551 Train Loss: 0.5692
# Epoch 12 Step 601 Train Loss: 0.5968
# Epoch 12 Step 651 Train Loss: 0.6631
# Epoch 12 Step 701 Train Loss: 0.5918
# Epoch 12 Step 751 Train Loss: 0.5354
# Epoch 12 Step 801 Train Loss: 0.6103
# Epoch 12 Step 851 Train Loss: 0.6296
# Epoch 12 Step 901 Train Loss: 0.6198
# Epoch 12 Step 951 Train Loss: 0.5003
# Epoch 12 Step 1001 Train Loss: 0.6393
# Epoch 12 Step 1051 Train Loss: 0.6154
# Epoch 12 Step 1101 Train Loss: 0.6385
# Epoch 12 Step 1151 Train Loss: 0.5549
# Epoch 12 Step 1201 Train Loss: 0.5624
# Epoch 12 Step 1251 Train Loss: 0.5257
# Epoch 12 Step 1301 Train Loss: 0.5658
# Epoch 12 Step 1351 Train Loss: 0.5107
# Epoch 12 Step 1401 Train Loss: 0.6258
# Epoch 12 Step 1451 Train Loss: 0.6520
# Epoch 12 Step 1501 Train Loss: 0.6576
# Epoch 12 Step 1551 Train Loss: 0.5941
# Epoch 12 Step 1601 Train Loss: 0.5860
# Epoch 12: Train Overall MSE: 0.0027 Validation Overall MSE: 0.0031.
# Train Top 20 DE MSE: 0.0616 Validation Top 20 DE MSE: 0.1133.
# Epoch 13 Step 1 Train Loss: 0.5305
# Epoch 13 Step 51 Train Loss: 0.6745
# Epoch 13 Step 101 Train Loss: 0.5850
# Epoch 13 Step 151 Train Loss: 0.5873
# Epoch 13 Step 201 Train Loss: 0.5731
# Epoch 13 Step 251 Train Loss: 0.6374
# Epoch 13 Step 301 Train Loss: 0.6277
# Epoch 13 Step 351 Train Loss: 0.5092
# Epoch 13 Step 401 Train Loss: 0.6056
# Epoch 13 Step 451 Train Loss: 0.6450
# Epoch 13 Step 501 Train Loss: 0.6476
# Epoch 13 Step 551 Train Loss: 0.6179
# Epoch 13 Step 601 Train Loss: 0.5263
# Epoch 13 Step 651 Train Loss: 0.5292
# Epoch 13 Step 701 Train Loss: 0.6419
# Epoch 13 Step 751 Train Loss: 0.5372
# Epoch 13 Step 801 Train Loss: 0.6069
# Epoch 13 Step 851 Train Loss: 0.5995
# Epoch 13 Step 901 Train Loss: 0.5995
# Epoch 13 Step 951 Train Loss: 0.6437
# Epoch 13 Step 1001 Train Loss: 0.5626
# Epoch 13 Step 1051 Train Loss: 0.6665
# Epoch 13 Step 1101 Train Loss: 0.5197
# Epoch 13 Step 1151 Train Loss: 0.5499
# Epoch 13 Step 1201 Train Loss: 0.5775
# Epoch 13 Step 1251 Train Loss: 0.6652
# Epoch 13 Step 1301 Train Loss: 0.6143
# Epoch 13 Step 1351 Train Loss: 0.6071
# Epoch 13 Step 1401 Train Loss: 0.5811
# Epoch 13 Step 1451 Train Loss: 0.6506
# Epoch 13 Step 1501 Train Loss: 0.6143
# Epoch 13 Step 1551 Train Loss: 0.6309
# Epoch 13 Step 1601 Train Loss: 0.5940
# Epoch 13: Train Overall MSE: 0.0028 Validation Overall MSE: 0.0032.
# Train Top 20 DE MSE: 0.0614 Validation Top 20 DE MSE: 0.1140.
# Epoch 14 Step 1 Train Loss: 0.5599
# Epoch 14 Step 51 Train Loss: 0.5933
# Epoch 14 Step 101 Train Loss: 0.5716
# Epoch 14 Step 151 Train Loss: 0.5676
# Epoch 14 Step 201 Train Loss: 0.5737
# Epoch 14 Step 251 Train Loss: 0.5070
# Epoch 14 Step 301 Train Loss: 0.6109
# Epoch 14 Step 351 Train Loss: 0.6085
# Epoch 14 Step 401 Train Loss: 0.6948
# Epoch 14 Step 451 Train Loss: 0.5790
# Epoch 14 Step 501 Train Loss: 0.5295
# Epoch 14 Step 551 Train Loss: 0.5928
# Epoch 14 Step 601 Train Loss: 0.7545
# Epoch 14 Step 651 Train Loss: 0.5012
# Epoch 14 Step 701 Train Loss: 0.6722
# Epoch 14 Step 751 Train Loss: 0.5642
# Epoch 14 Step 801 Train Loss: 0.5689
# Epoch 14 Step 851 Train Loss: 0.5658
# Epoch 14 Step 901 Train Loss: 0.6454
# Epoch 14 Step 951 Train Loss: 0.5237
# Epoch 14 Step 1001 Train Loss: 0.6069
# Epoch 14 Step 1051 Train Loss: 0.6501
# Epoch 14 Step 1101 Train Loss: 0.7099
# Epoch 14 Step 1151 Train Loss: 0.6487
# Epoch 14 Step 1201 Train Loss: 0.5815
# Epoch 14 Step 1251 Train Loss: 0.6414
# Epoch 14 Step 1301 Train Loss: 0.5828
# Epoch 14 Step 1351 Train Loss: 0.6177
# Epoch 14 Step 1401 Train Loss: 0.5724
# Epoch 14 Step 1451 Train Loss: 0.5350
# Epoch 14 Step 1501 Train Loss: 0.5557
# Epoch 14 Step 1551 Train Loss: 0.5604
# Epoch 14 Step 1601 Train Loss: 0.6112
# Epoch 14: Train Overall MSE: 0.0027 Validation Overall MSE: 0.0032.
# Train Top 20 DE MSE: 0.0596 Validation Top 20 DE MSE: 0.1143.
# Epoch 15 Step 1 Train Loss: 0.5795
# Epoch 15 Step 51 Train Loss: 0.5466
# Epoch 15 Step 101 Train Loss: 0.5870
# Epoch 15 Step 151 Train Loss: 0.5522
# Epoch 15 Step 201 Train Loss: 0.5950
# Epoch 15 Step 251 Train Loss: 0.5386
# Epoch 15 Step 301 Train Loss: 0.5342
# Epoch 15 Step 351 Train Loss: 0.6323
# Epoch 15 Step 401 Train Loss: 0.6087
# Epoch 15 Step 451 Train Loss: 0.5738
# Epoch 15 Step 501 Train Loss: 0.5878
# Epoch 15 Step 551 Train Loss: 0.6444
# Epoch 15 Step 601 Train Loss: 0.5609
# Epoch 15 Step 651 Train Loss: 0.6127
# Epoch 3 Step 851 Train Loss: 0.6558
# Epoch 3 Step 901 Train Loss: 0.5644
# Epoch 3 Step 951 Train Loss: 0.5416
# Epoch 3 Step 1001 Train Loss: 0.5166
# Epoch 3 Step 1051 Train Loss: 0.4982
# Epoch 3 Step 1101 Train Loss: 0.5620
# Epoch 3 Step 1151 Train Loss: 0.5570
# Epoch 3 Step 1201 Train Loss: 0.5429
# Epoch 3 Step 1251 Train Loss: 0.7384
# Epoch 3 Step 1301 Train Loss: 0.6377
# Epoch 3 Step 1351 Train Loss: 0.6158
# Epoch 3 Step 1401 Train Loss: 0.5505
# Epoch 3 Step 1451 Train Loss: 0.5379
# Epoch 3 Step 1501 Train Loss: 0.5332
# Epoch 3 Step 1551 Train Loss: 0.5156
# Epoch 3 Step 1601 Train Loss: 0.5154
# ...
# Epoch 5 Step 601 Train Loss: 0.4982
# Epoch 5 Step 651 Train Loss: 0.5319
# Epoch 5 Step 701 Train Loss: 0.5685
# Epoch 5 Step 751 Train Loss: 0.5769
# Epoch 5 Step 801 Train Loss: 0.5792
# Epoch 5 Step 851 Train Loss: 0.5552
# Epoch 5 Step 901 Train Loss: 0.5867
# Epoch 5 Step 951 Train Loss: 0.5344
# Epoch 5 Step 1001 Train Loss: 0.5453
# Epoch 5 Step 1051 Train Loss: 0.5359
# Epoch 5 Step 1101 Train Loss: 0.5623
# Epoch 5 Step 1151 Train Loss: 0.6908
# Epoch 5 Step 1201 Train Loss: 0.6158
# Epoch 5 Step 1251 Train Loss: 0.5023
# Epoch 5 Step 1301 Train Loss: 0.6537
# Epoch 5 Step 1351 Train Loss: 0.6074
# Epoch 5 Step 1401 Train Loss: 0.5575
# Epoch 5 Step 1451 Train Loss: 0.6379
# Epoch 5 Step 1501 Train Loss: 0.5517
# Epoch 5 Step 1551 Train Loss: 0.5177
# Epoch 5 Step 1601 Train Loss: 0.5723
# Epoch 5 Step 1651 Train Loss: 0.4989
# Epoch 5: Train Overall MSE: 0.0027 Validation Overall MSE: 0.0045.
# Train Top 20 DE MSE: 0.0580 Validation Top 20 DE MSE: 0.1456.
# Epoch 6 Step 1 Train Loss: 0.5848
# Epoch 6 Step 51 Train Loss: 0.5226
# Epoch 6 Step 101 Train Loss: 0.5945
# Epoch 6 Step 151 Train Loss: 0.5470
# Epoch 6 Step 201 Train Loss: 0.5703
# Epoch 6 Step 251 Train Loss: 0.4995
# Epoch 6 Step 301 Train Loss: 0.5288
# Epoch 6 Step 351 Train Loss: 0.5814
# Epoch 6 Step 401 Train Loss: 0.5745
# Epoch 6 Step 451 Train Loss: 0.5168
# Epoch 6 Step 501 Train Loss: 0.5915
# Epoch 6 Step 551 Train Loss: 0.5956
# Epoch 6 Step 601 Train Loss: 0.6774
# Epoch 6 Step 651 Train Loss: 0.5521
# Epoch 6 Step 701 Train Loss: 0.6105
# Epoch 6 Step 751 Train Loss: 0.5575
# Epoch 6 Step 801 Train Loss: 0.5456
# Epoch 6 Step 851 Train Loss: 0.5816
# Epoch 6 Step 901 Train Loss: 0.6582
# Epoch 6 Step 951 Train Loss: 0.5592
# Epoch 6 Step 1001 Train Loss: 0.5308
# Epoch 6 Step 1051 Train Loss: 0.5010
# Epoch 6 Step 1101 Train Loss: 0.5340
# Epoch 6 Step 1151 Train Loss: 0.5890
# Epoch 6 Step 1201 Train Loss: 0.5731
# Epoch 6 Step 1251 Train Loss: 0.6292
# Epoch 6 Step 1301 Train Loss: 0.6419
# Epoch 6 Step 1351 Train Loss: 0.5743
# Epoch 6 Step 1401 Train Loss: 0.5350
# Epoch 6 Step 1451 Train Loss: 0.5325
# Epoch 6 Step 1501 Train Loss: 0.7071
# Epoch 6 Step 1551 Train Loss: 0.6286
# Epoch 6 Step 1601 Train Loss: 0.5287
# Epoch 6 Step 1651 Train Loss: 0.6029
# Epoch 6: Train Overall MSE: 0.0027 Validation Overall MSE: 0.0044.
# Train Top 20 DE MSE: 0.0593 Validation Top 20 DE MSE: 0.1244.
# Epoch 7 Step 1 Train Loss: 0.6179
# Epoch 7 Step 51 Train Loss: 0.5067
# Epoch 7 Step 101 Train Loss: 0.5896
# Epoch 7 Step 151 Train Loss: 0.5512
# Epoch 7 Step 201 Train Loss: 0.8013
# Epoch 7 Step 251 Train Loss: 0.6300
# Epoch 7 Step 301 Train Loss: 0.4991
# Epoch 7 Step 351 Train Loss: 0.4745
# Epoch 7 Step 401 Train Loss: 0.5288
# Epoch 7 Step 451 Train Loss: 0.6469
# Epoch 7 Step 501 Train Loss: 0.5540
# Epoch 7 Step 551 Train Loss: 0.6383
# Epoch 7 Step 601 Train Loss: 0.7279
# Epoch 7 Step 651 Train Loss: 0.6173
# Epoch 7 Step 701 Train Loss: 0.5549
# Epoch 7 Step 751 Train Loss: 0.6281
# Epoch 7 Step 801 Train Loss: 0.5872
# Epoch 7 Step 851 Train Loss: 0.7143
# Epoch 7 Step 901 Train Loss: 0.5990
# Epoch 7 Step 951 Train Loss: 0.6307
# Epoch 7 Step 1001 Train Loss: 0.5849
# Epoch 7 Step 1051 Train Loss: 0.5792
# Epoch 7 Step 1101 Train Loss: 0.5180
# Epoch 7 Step 1151 Train Loss: 0.6107
# Epoch 7 Step 1201 Train Loss: 0.4895
# Epoch 7 Step 1251 Train Loss: 0.7272
# Epoch 7 Step 1301 Train Loss: 0.5587
# Epoch 7 Step 1351 Train Loss: 0.6567
# Epoch 7 Step 1401 Train Loss: 0.6463
# Epoch 7 Step 1451 Train Loss: 0.5736
# Epoch 7 Step 1501 Train Loss: 0.5997
# Epoch 7 Step 1551 Train Loss: 0.5407
# Epoch 7 Step 1601 Train Loss: 0.5075
# Epoch 7 Step 1651 Train Loss: 0.5741
# Epoch 7: Train Overall MSE: 0.0027 Validation Overall MSE: 0.0044.
# Train Top 20 DE MSE: 0.0551 Validation Top 20 DE MSE: 0.1224.
# Epoch 8 Step 1 Train Loss: 0.5014
# Epoch 8 Step 51 Train Loss: 0.6015
# Epoch 8 Step 101 Train Loss: 0.5855
# Epoch 8 Step 151 Train Loss: 0.6126
# Epoch 8 Step 201 Train Loss: 0.5257
# Epoch 8 Step 251 Train Loss: 0.5827
# Epoch 8 Step 301 Train Loss: 0.4899
# Epoch 8 Step 351 Train Loss: 0.5401
# Epoch 8 Step 401 Train Loss: 0.5152
# Epoch 8 Step 451 Train Loss: 0.5488
# Epoch 11 Step 1251 Train Loss: 0.5569
# Epoch 11 Step 1301 Train Loss: 0.6011
# Epoch 11 Step 1351 Train Loss: 0.5091
# Epoch 11 Step 1401 Train Loss: 0.6937
# Epoch 11 Step 1451 Train Loss: 0.6423
# Epoch 11 Step 1501 Train Loss: 0.6041
# Epoch 11 Step 1551 Train Loss: 0.6091
# Epoch 11 Step 1601 Train Loss: 0.5566
# Epoch 11 Step 1651 Train Loss: 0.5891
# Epoch 11: Train Overall MSE: 0.0025 Validation Overall MSE: 0.0044.
# Train Top 20 DE MSE: 0.0593 Validation Top 20 DE MSE: 0.1412.
# Epoch 12 Step 1 Train Loss: 0.5255
# Epoch 12 Step 51 Train Loss: 0.6007
# Epoch 12 Step 101 Train Loss: 0.6022
# Epoch 12 Step 151 Train Loss: 0.5466
# Epoch 12 Step 201 Train Loss: 0.7328
# Epoch 12 Step 251 Train Loss: 0.5604
# Epoch 12 Step 301 Train Loss: 0.5798
# Epoch 12 Step 351 Train Loss: 0.5439
# Epoch 12 Step 401 Train Loss: 0.6464
# Epoch 12 Step 451 Train Loss: 0.5398
# Epoch 12 Step 501 Train Loss: 0.5280
# Epoch 12 Step 551 Train Loss: 0.5697
# Epoch 12 Step 601 Train Loss: 0.5219
# Epoch 12 Step 651 Train Loss: 0.5979
# Epoch 12 Step 701 Train Loss: 0.5785
# Epoch 12 Step 751 Train Loss: 0.6457
# Epoch 12 Step 801 Train Loss: 0.6528
# Epoch 12 Step 851 Train Loss: 0.6387
# Epoch 12 Step 901 Train Loss: 0.7245
# Epoch 12 Step 951 Train Loss: 0.6034
# Epoch 12 Step 1001 Train Loss: 0.5309
# Epoch 12 Step 1051 Train Loss: 0.5242
# Epoch 12 Step 1101 Train Loss: 0.5110
# Epoch 12 Step 1151 Train Loss: 0.6143
# Epoch 12 Step 1201 Train Loss: 0.6084
# Epoch 12 Step 1251 Train Loss: 0.4797
# Epoch 12 Step 1301 Train Loss: 0.5128
# Epoch 12 Step 1351 Train Loss: 0.5622
# Epoch 12 Step 1401 Train Loss: 0.6519
# Epoch 12 Step 1451 Train Loss: 0.6143
# Epoch 12 Step 1501 Train Loss: 0.5680
# Epoch 12 Step 1551 Train Loss: 0.5524
# Epoch 12 Step 1601 Train Loss: 0.4944
# Epoch 12 Step 1651 Train Loss: 0.5299
# Epoch 12: Train Overall MSE: 0.0026 Validation Overall MSE: 0.0044.
# Train Top 20 DE MSE: 0.0610 Validation Top 20 DE MSE: 0.1392.
# Epoch 13 Step 1 Train Loss: 0.5637
# Epoch 13 Step 51 Train Loss: 0.5842
# Epoch 13 Step 101 Train Loss: 0.5925
# Epoch 13 Step 151 Train Loss: 0.6183
# Epoch 13 Step 201 Train Loss: 0.5739
# Epoch 13 Step 251 Train Loss: 0.7204
# Epoch 13 Step 301 Train Loss: 0.5179
# Epoch 13 Step 351 Train Loss: 0.5783
# Epoch 13 Step 401 Train Loss: 0.5908
# Epoch 13 Step 451 Train Loss: 0.5575
# Epoch 13 Step 501 Train Loss: 0.6226
# Epoch 13 Step 551 Train Loss: 0.7171
# Epoch 13 Step 601 Train Loss: 0.5279
# Epoch 13 Step 651 Train Loss: 0.6189
# Epoch 13 Step 701 Train Loss: 0.6226
# Epoch 13 Step 751 Train Loss: 0.5543
# Epoch 13 Step 801 Train Loss: 0.5809
# Epoch 13 Step 851 Train Loss: 0.5944
# Epoch 13 Step 901 Train Loss: 0.5695
# Epoch 13 Step 951 Train Loss: 0.5175
# Epoch 13 Step 1001 Train Loss: 0.5810
# Epoch 13 Step 1051 Train Loss: 0.5645
# Epoch 13 Step 1101 Train Loss: 0.5474
# Epoch 13 Step 1151 Train Loss: 0.5757
# Epoch 13 Step 1201 Train Loss: 0.5848
# Epoch 13 Step 1251 Train Loss: 0.5683
# Epoch 13 Step 1301 Train Loss: 0.5121
# Epoch 13 Step 1351 Train Loss: 0.7009
# Epoch 13 Step 1401 Train Loss: 0.6053
# Epoch 13 Step 1451 Train Loss: 0.4835
# Epoch 13 Step 1501 Train Loss: 0.5530
# Epoch 13 Step 1551 Train Loss: 0.5771
# Epoch 13 Step 1601 Train Loss: 0.6559
# Epoch 13 Step 1651 Train Loss: 0.6456
# Epoch 13: Train Overall MSE: 0.0026 Validation Overall MSE: 0.0044.
# Train Top 20 DE MSE: 0.0620 Validation Top 20 DE MSE: 0.1453.
# Epoch 14 Step 1 Train Loss: 0.7480
# Epoch 14 Step 51 Train Loss: 0.8634
# Epoch 14 Step 101 Train Loss: 0.6399
# Epoch 14 Step 151 Train Loss: 0.6413
# Epoch 14 Step 201 Train Loss: 0.5490
# Epoch 14 Step 251 Train Loss: 0.5908
# Epoch 14 Step 301 Train Loss: 0.6114
# Epoch 14 Step 351 Train Loss: 0.8227
# Epoch 14 Step 401 Train Loss: 0.6154
# Epoch 14 Step 451 Train Loss: 0.6146
# Epoch 14 Step 501 Train Loss: 0.5675
# Epoch 14 Step 551 Train Loss: 0.5456
# Epoch 14 Step 601 Train Loss: 0.5205
# Epoch 14 Step 651 Train Loss: 0.6102
# Epoch 14 Step 701 Train Loss: 0.5590
# Epoch 14 Step 751 Train Loss: 0.5540
# Epoch 14 Step 801 Train Loss: 0.5794
# Epoch 14 Step 851 Train Loss: 0.5094
# Epoch 14 Step 901 Train Loss: 0.5351
# Epoch 14 Step 951 Train Loss: 0.5604
# Epoch 14 Step 1001 Train Loss: 0.5073
# Epoch 14 Step 1051 Train Loss: 0.5688
# Epoch 14 Step 1101 Train Loss: 0.5861
# Epoch 14 Step 1151 Train Loss: 0.5513
# Epoch 14 Step 1201 Train Loss: 0.5714
# Epoch 14 Step 1251 Train Loss: 0.5536
# Epoch 14 Step 1301 Train Loss: 0.5523
# Epoch 14 Step 1351 Train Loss: 0.5673
# Epoch 14 Step 1401 Train Loss: 0.5717
# Epoch 14 Step 1451 Train Loss: 0.5244
# Epoch 14 Step 1501 Train Loss: 0.6195
# Epoch 14 Step 1551 Train Loss: 0.5649
# Epoch 14 Step 1601 Train Loss: 0.5592
# Epoch 14 Step 1651 Train Loss: 0.4864
# Epoch 14: Train Overall MSE: 0.0027 Validation Overall MSE: 0.0045.
# Train Top 20 DE MSE: 0.0632 Validation Top 20 DE MSE: 0.1412.
# Epoch 15 Step 1 Train Loss: 0.5876
# Epoch 15 Step 51 Train Loss: 0.5804
# Epoch 15 Step 101 Train Loss: 0.5240
# Epoch 15 Step 151 Train Loss: 0.6367
# Epoch 15 Step 201 Train Loss: 0.6132
# Epoch 15 Step 251 Train Loss: 0.6109
# Epoch 15 Step 301 Train Loss: 0.5517
# Epoch 15 Step 351 Train Loss: 0.5022
# Epoch 15 Step 401 Train Loss: 0.5441
# Epoch 15 Step 451 Train Loss: 0.5508
# Epoch 15 Step 501 Train Loss: 0.8624
# Epoch 15 Step 551 Train Loss: 0.5253
# Epoch 15 Step 601 Train Loss: 0.5832
# Epoch 15 Step 651 Train Loss: 0.5825
# Epoch 15 Step 701 Train Loss: 0.5829
# Epoch 15 Step 751 Train Loss: 0.5250
# Epoch 15 Step 801 Train Loss: 0.7346
# Epoch 15 Step 851 Train Loss: 0.6136
# Epoch 15 Step 901 Train Loss: 0.6348
# Epoch 15 Step 951 Train Loss: 0.5771
# Epoch 15 Step 1001 Train Loss: 0.5684
# Epoch 15 Step 1051 Train Loss: 0.6170
# Epoch 15 Step 1101 Train Loss: 0.6770
# Epoch 15 Step 1151 Train Loss: 0.4765
# Epoch 15 Step 1201 Train Loss: 0.7112
# Epoch 15 Step 1251 Train Loss: 0.6798
# Epoch 15 Step 1301 Train Loss: 0.5347
# Epoch 15 Step 1351 Train Loss: 0.5129
# Epoch 15 Step 1401 Train Loss: 0.5052
# Epoch 15 Step 1451 Train Loss: 0.5561
# Epoch 15 Step 1501 Train Loss: 0.5510
# Epoch 15 Step 1551 Train Loss: 0.6014
# Epoch 15 Step 1601 Train Loss: 0.6232
# Epoch 15 Step 1651 Train Loss: 0.5769
# Epoch 15: Train Overall MSE: 0.0027 Validation Overall MSE: 0.0045.
# Train Top 20 DE MSE: 0.0676 Validation Top 20 DE MSE: 0.1500.
# Done!
# Start Testing...
# Best performing model: Test Top 20 DE MSE: 0.1341
# Start doing subgroup analysis for simulation split...
# test_combo_seen0_mse: nan
# test_combo_seen0_pearson: nan
# test_combo_seen0_mse_de: nan
# test_combo_seen0_pearson_de: nan
# test_combo_seen1_mse: nan
# test_combo_seen1_pearson: nan
# test_combo_seen1_mse_de: nan
# test_combo_seen1_pearson_de: nan
# test_combo_seen2_mse: nan
# test_combo_seen2_pearson: nan
# test_combo_seen2_mse_de: nan
# test_combo_seen2_pearson_de: nan
# test_unseen_single_mse: 0.0041481266
# test_unseen_single_pearson: 0.9931167273093484
# test_unseen_single_mse_de: 0.13412082
# test_unseen_single_pearson_de: 0.9624127035542506
# test_combo_seen0_mse: nan
# test_combo_seen0_pearson: nan
# test_combo_seen0_mse_de: nan
# test_combo_seen0_pearson_de: nan
# test_combo_seen1_mse: nan
# test_combo_seen1_pearson: nan
# test_combo_seen1_mse_de: nan
# test_combo_seen1_pearson_de: nan
# test_combo_seen2_mse: nan
# test_combo_seen2_pearson: nan
# test_combo_seen2_mse_de: nan
# test_combo_seen2_pearson_de: nan
# test_unseen_single_mse: 0.0041481266
# test_unseen_single_pearson: 0.9931167273093484
# test_unseen_single_mse_de: 0.13412082
# test_unseen_single_pearson_de: 0.9624127035542506
# Done!

# %%
no_perturb_mse_de_seeds = pd.DataFrame(res)
res_gears = {}
res_gears_normalized = {}
for key in subgroup_analysis_gears:
    res_gears[f"mse_de_seed{key}"] = pd.DataFrame(subgroup_analysis_gears[key]).T["mse_de"]
    res_gears_normalized[f"mse_de_seed{key}"] = pd.DataFrame(subgroup_analysis_gears[key]).T["mse_de"] / no_perturb_mse_de_seeds[f"mse_de_seed{key}"]

# %%
with open(DATA_DIR_LCL + "gears_subgroup_analysis.pkl", "wb") as f:
    pickle.dump(subgroup_analysis_gears, f)

# %%
pd.DataFrame(res_gears).to_csv(DATA_DIR_LCL + "gears_mse_de_seeds.csv")

# %%
pd.DataFrame(res_gears_normalized).to_csv(DATA_DIR_LCL + "gears_normalized_mse_de_seeds.csv")
